# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy
from scipy.io import arff
from pylab import rcParams

data = pd.Series((5, 2, 7)) # Verify installation by making a small series
print(data)
# Out:
# 0    5
# 1    2
# 2    7
# dtype: int64

# %%
# Making a dataframe
data = {
       'Weight': [92, 70, 58, 99, 55, 76, 62, 92, 71, 70, 77, 79],
       'Exercise': [6, 6, 6, 2, 8, 4, 6, 6, 5, 6, 4, 4],
       'Cholesterol' : [4.8, 5.1, 6.4, 6.5, 2.3, 5.7, 4.2, 6.9, 4.8, 4.8, 7.7, 5.7],
       'Income' : [2060, 2660, 2530, 1740, 3520, 3750, 2720, 3130, 2100, 3340, 2430, 2700],
       'Happiness' : [49, 36, 49, 28, 77, 55, 43, 39, 54, 29, 53, 47],
       'Birthyear' : [1953, 1955, 1939, 1942, 1989, 1937, 1979, 1905, 1995, 1966, 1938, 1993]}
df = pd.DataFrame(data)

df.index.names = ['Id']  # Change index name
df.index +=1             # Start index numbers from 1
df.index.rename('id', inplace=False)
print(df.reset_index().to_string(index=False))
# Out:
#  Id  Weight  Exercise  Cholesterol  Income  Happiness  Birthyear
#   1      92         6          4.8    2060         49       1953
#   2      70         6          5.1    2660         36       1955
#   3      58         6          6.4    2530         49       1939
#   4      99         2          6.5    1740         28       1942
#   5      55         8          2.3    3520         77       1989
#   6      76         4          5.7    3750         55       1937
#   7      62         6          4.2    2720         43       1979
#   8      92         6          6.9    3130         39       1905
#   9      71         5          4.8    2100         54       1995
#  10      70         6          4.8    3340         29       1966
#  11      77         4          7.7    2430         53       1938
#  12      79         4          5.7    2700         47       1993

# %%
res = df.describe() # Calculate the basic statistics
print(res)
# Out:
#           Weight   Exercise  Cholesterol       Income  Happiness    Birthyear
# count  12.000000  12.000000    12.000000    12.000000  12.000000    12.000000
# mean   75.083333   5.250000     5.408333  2723.333333  46.583333  1957.583333
# std    13.813421   1.544786     1.419000   614.807188  13.283334    27.566311
# min    55.000000   2.000000     2.300000  1740.000000  28.000000  1905.000000
# 25%    68.000000   4.000000     4.800000  2347.500000  38.250000  1938.750000
# 50%    73.500000   6.000000     5.400000  2680.000000  48.000000  1954.000000
# 75%    82.250000   6.000000     6.425000  3182.500000  53.250000  1981.500000
# max    99.000000   8.000000     7.700000  3750.000000  77.000000  1995.000000

# %%
mean = df['Income'].mean() # Calculate mean income

# Iterating through rows
for i, row in df.iterrows():
    if row['Income'] < mean:
        print('Person', i, 'below average income')
    else:
        print('Person', i, 'above average income')
# Out:
# Person 1 below average income
# Person 2 below average income
# Person 3 below average income
# Person 4 below average income
# Person 5 above average income
# Person 6 above average income
# Person 7 below average income
# Person 8 above average income
# Person 9 below average income
# Person 10 above average income
# Person 11 below average income
# Person 12 below average income

# %%
data2 = pd.read_csv('kd.csv')
df2 = pd.DataFrame(data2)
df2 = df2[(df2 != '?').all(axis=1)]  # Remove columns, that contains '?''
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows
df2
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 9    53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# 11   63   70  1.010  3  0  abnormal  abnormal     present  notpresent  380
# 14   68   80  1.010  3  2    normal  abnormal     present     present  157
# 20   61   80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
# 22   48   80  1.025  4  0    normal  abnormal  notpresent  notpresent   95
# 27   69   70  1.010  3  4    normal  abnormal  notpresent  notpresent  264
# 48   73   70  1.005  0  0    normal    normal  notpresent  notpresent   70
# 58   73   80  1.020  2  0  abnormal  abnormal  notpresent  notpresent  253
# 71   46   60  1.010  1  0    normal    normal  notpresent  notpresent  163
# 74   56   90  1.015  2  0  abnormal  abnormal  notpresent  notpresent  129
# ...

# %%
convert_dict = {'age': float, # Change all objects to float and remove any rows that contains strings
                'bp': float,
                'sg': float,
                'al': float,
                'su': float,
                'bgr': float,
                'bu': float,
                'bu': float,
                'sc': float,
                'sod': float,
                'pot': float,
                'hemo': float,
                'pcv': float,
                'wbcc': float,
                'rbcc': float,
               } 
df2 = df2.astype(convert_dict1) 

# Calculate the min, max and mean values
print("Minimum values", "\n", "\n", df2.min(), 
"\n", "\n", "Maximum values", "\n", "\n", df2.max(), 
"\n", "\n", "Mean values", "\n", "\n", df2.mean())
# Out:
# Minimum values
#
#  age               6
# bp               50
# sg            1.005
# al                0
# su                0
# rbc        abnormal
# pc         abnormal
# pcc      notpresent
# ba       notpresent
# bgr              70
# bu               10
# sc              0.4
# sod             111
# pot             2.5
# hemo            3.1
# pcv               9
# wbcc           3800
# rbcc            2.1
# htn              no
# dm               no
# cad              no
# appet          good
# pe               no
# ane              no
# class           ckd
# dtype: object
#
#  Maximum values
#
#  age           83
# bp           110
# sg         1.025
# al             4
# su             5
# rbc       normal
# pc        normal
# pcc      present
# ba       present
# bgr          490
# bu           309
# sc          15.2
# sod          150
# pot           47
# hemo        17.8
# pcv           54
# wbcc       26400
# rbcc           8
# htn          yes
# dm           yes
# ...

# %%
pearsoncorr = df2.corr(method='pearson') # Calculate correlations
pearsoncorr
# Out:
#            age        bp        sg        al        su       bgr        bu  \
# age   1.000000  0.079712 -0.277303  0.253380  0.207711  0.301915  0.190636
# bp    0.079712  1.000000 -0.198897  0.322507  0.243828  0.190113  0.316287
# sg   -0.277303 -0.198897  1.000000 -0.712331 -0.448477 -0.544781 -0.545319
# al    0.253380  0.322507 -0.712331  1.000000  0.521448  0.518123  0.661940
# su    0.207711  0.243828 -0.448477  0.521448  1.000000  0.730050  0.312259
# bgr   0.301915  0.190113 -0.544781  0.518123  0.730050  1.000000  0.326496
# bu    0.190636  0.316287 -0.545319  0.661940  0.312259  0.326496  1.000000
# sc    0.189721  0.386551 -0.563122  0.702889  0.347196  0.331284  0.896094
# sod  -0.102933 -0.224710  0.539285 -0.599334 -0.242491 -0.284968 -0.492778
# pot   0.006866  0.127801 -0.075057  0.209492  0.271954  0.102226  0.245427
# hemo -0.245645 -0.282365  0.682086 -0.784745 -0.385511 -0.434158 -0.712196
# ...

# %%
rcParams['figure.figsize'] = 10, 10  # Change figure size
names = ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
correlations = pearsoncorr

# Plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,14,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()
